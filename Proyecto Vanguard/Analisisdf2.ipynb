# %%
import pandas as pd 

df2 = pd.read_csv("/Users/rodri/Downloads/df_final_demo.txt")
df2
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df2.shape
# Out:
# (70609, 9)

# %%
df2.info
# Out:
# <bound method DataFrame.info of        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df2.isnull().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df2=df2.dropna()

# %%
df2.isnull().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# dtype: int64

# %%
df2.shape
# Out:
# (70594, 9)

# %%
df2 = df2.rename(columns = {"gendr":"gender"})
df2
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gender  \
# 0         836976             6.0              73.0      60.5      U
# 1        2304905             7.0              94.0      58.0      U
# 2        1439522             5.0              64.0      32.0      U
# 3        1562045            16.0             198.0      49.0      M
# 4        5126305            12.0             145.0      33.0      F
# ...          ...             ...               ...       ...    ...
# 70604    7993686             4.0              56.0      38.5      U
# 70605    8981690            12.0             148.0      31.0      M
# 70606     333913            16.0             198.0      61.5      F
# 70607    1573142            21.0             255.0      68.0      M
# 70608    5602139            21.0             254.0      59.5      F
#
#        num_accts         bal  calls_6_mnth  logons_6_mnth
# 0            2.0    45105.30           6.0            9.0
# ...

# %%
df2["gender"].unique()
# Out:
# array(['U', 'M', 'F', 'X'], dtype=object)

# %%
df2['gender'] = df2['gender'].replace({'X': 'U'})

# %%
df2["gender"].unique()
# Out:
# array(['U', 'M', 'F'], dtype=object)

# %%
df2.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.059400e+04    70594.000000      70594.000000  70594.000000
# mean   5.005026e+06       12.053007        150.659999     46.442240
# std    2.877289e+06        6.871850         82.090264     15.591273
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519543e+06        6.000000         82.000000     32.500000
# 50%    5.016974e+06       11.000000        136.000000     47.000000
# 75%    7.483074e+06       16.000000        192.000000     59.000000
# max    9.999839e+06       62.000000        749.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  70594.000000  7.059400e+04  70594.000000   70594.000000
# mean       2.255532  1.474467e+05      3.382469       5.566720
# std        0.535000  3.015106e+05      2.236595       2.353296
# min        1.000000  1.378942e+04      0.000000       1.000000
# ...

# %%
df2.describe(include="object")
# Out:
#        gender
# count   70594
# unique      3
# top         U
# freq    24125

# %%
df2.to_csv("df_demographic.csv", index= False)

# %%
my_table = pd.crosstab(index = df2["gender"],  # Make a crosstab
                              columns="count")      # Name the count column
my_table
# Out:
# col_0   count
# gender
# F       22745
# M       23724
# U       24125

# %%
import seaborn as sns

# %%
sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_5088/2993794703.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");

# %% [markdown]
# El grafico demuestra una distribucion muy igualada entre los 3 generos, sin embargo el grupo unknown es el que mas usuarios tiene

# %%
df2.columns
# Out:
# Index(['client_id', 'clnt_tenure_yr', 'clnt_tenure_mnth', 'clnt_age', 'gender',
#        'num_accts', 'bal', 'calls_6_mnth', 'logons_6_mnth'],
#       dtype='object')

# %%
correlation = df2['clnt_tenure_yr'].corr(df2['clnt_tenure_mnth'], method='spearman')
correlation
# Out:
# 0.9981034767625402

# %%
import seaborn as sns 
sns.scatterplot(data=df2, x='clnt_tenure_yr', y='clnt_tenure_mnth')
# Out:
# <Axes: xlabel='clnt_tenure_yr', ylabel='clnt_tenure_mnth'>

# %%
df2= df2.drop(columns = "clnt_tenure_mnth")
df2.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_age gender  num_accts        bal  \
# 0     836976             6.0      60.5      U        2.0   45105.30
# 1    2304905             7.0      58.0      U        2.0  110860.30
# 2    1439522             5.0      32.0      U        2.0   52467.79
# 3    1562045            16.0      49.0      M        2.0   67454.65
# 4    5126305            12.0      33.0      F        2.0  103671.75
#
#    calls_6_mnth  logons_6_mnth
# 0           6.0            9.0
# 1           6.0            9.0
# 2           6.0            9.0
# 3           3.0            6.0
# 4           0.0            3.0

# %% [markdown]
# Podemos ver que la correlacion entre tenure_yr y tenure_mnth es muy alta debido a que indican lo mismo pero uno en meses y otro en años por lo tanto podemos prescindir de una de las columnas

# %% [markdown]
# ## Analisis de la columna Age

# %%
mean_age = df2['clnt_age'].mean().round(2)
min_age = df2['clnt_age'].min()
max_age = df2['clnt_age'].max()
range_age = max_age - min_age

mean_age, min_age,max_age,range_age
# Out:
# (46.44, 13.5, 96.0, 82.5)

# %% [markdown]
# La media de edad es 46.44
#
# El minimo de edad es de 13,5
#
# El maximo es de 96
#
# Lo que da un rango de edad de 82,5

# %%
df2.clnt_age.unique()
# Out:
# array([60.5, 58. , 32. , 49. , 33. , 30.5, 58.5, 57.5, 67.5, 54.5, 34.5,
#        51.5, 62.5, 36. , 74. , 32.5, 31. , 25.5, 42.5, 42. , 30. , 55. ,
#        38. , 68.5, 52.5, 54. , 63. , 48. , 66.5, 68. , 65. , 51. , 46. ,
#        63.5, 23. , 26.5, 56.5, 76.5, 27.5, 39.5, 25. , 27. , 60. , 66. ,
#        39. , 56. , 40. , 52. , 31.5, 43.5, 35. , 19. , 64.5, 64. , 22.5,
#        33.5, 36.5, 61. , 40.5, 72. , 44.5, 28.5, 59.5, 45. , 18. , 78. ,
#        50.5, 29. , 37.5, 57. , 70. , 74.5, 22. , 50. , 53. , 62. , 65.5,
#        29.5, 28. , 69.5, 35.5, 71.5, 34. , 38.5, 69. , 43. , 83.5, 21.5,
#        47. , 61.5, 73.5, 71. , 59. , 21. , 44. , 83. , 47.5, 72.5, 76. ,
#        78.5, 55.5, 67. , 41.5, 20.5, 75. , 24. , 79. , 26. , 41. , 23.5,
#        49.5, 46.5, 45.5, 48.5, 24.5, 75.5, 80. , 73. , 87. , 19.5, 53.5,
#        18.5, 70.5, 80.5, 86. , 37. , 85. , 17.5, 82. , 20. , 77.5, 77. ,
#        79.5, 88.5, 96. , 81. , 81.5, 88. , 84. , 94.5, 89. , 92. , 82.5,
# ...

# %%
def categorize_age(age):
    if 13 <= age < 30:
        return 'young'
    elif 30 <= age < 60:
        return 'adult'
    elif 60 <= age < 100:
        return 'senior'
    else:
        return 'fuera de rango'

# Aplicar la función de mapeo a la columna 'edad' para crear la nueva columna 'rango de edad'
df2['grupo_edad'] = df2['clnt_age'].map(categorize_age)

# Mostrar el DataFrame resultante
df2.head(10)
# Out:
#    client_id  clnt_tenure_yr  clnt_age gender  num_accts        bal  \
# 0     836976             6.0      60.5      U        2.0   45105.30
# 1    2304905             7.0      58.0      U        2.0  110860.30
# 2    1439522             5.0      32.0      U        2.0   52467.79
# 3    1562045            16.0      49.0      M        2.0   67454.65
# 4    5126305            12.0      33.0      F        2.0  103671.75
# 5    3727881             5.0      30.5      U        2.0   23915.60
# 6     272934             5.0      58.5      U        2.0   27021.42
# 7     388801            30.0      57.5      M        5.0  522498.72
# 8     285619            30.0      67.5      M        2.0  299388.72
# 9    8198645            15.0      54.5      F        2.0  382303.83
#
#    calls_6_mnth  logons_6_mnth grupo_edad
# 0           6.0            9.0     senior
# 1           6.0            9.0      adult
# 2           6.0            9.0      adult
# 3           3.0            6.0      adult
# ...

# %%
my_table = pd.crosstab(index = df2["grupo_edad"],  
                              columns="count")      
my_table
# Out:
# col_0       count
# grupo_edad
# adult       41076
# senior      16219
# young       13299

# %%
import seaborn as sns
sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_5088/2095407100.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");

# %% [markdown]
# Podemos ver que el grupo donde la mayoria de usuarios se encuentra es adulto

# %%
df2.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_age gender  num_accts        bal  \
# 0     836976             6.0      60.5      U        2.0   45105.30
# 1    2304905             7.0      58.0      U        2.0  110860.30
# 2    1439522             5.0      32.0      U        2.0   52467.79
# 3    1562045            16.0      49.0      M        2.0   67454.65
# 4    5126305            12.0      33.0      F        2.0  103671.75
#
#    calls_6_mnth  logons_6_mnth grupo_edad
# 0           6.0            9.0     senior
# 1           6.0            9.0      adult
# 2           6.0            9.0      adult
# 3           3.0            6.0      adult
# 4           0.0            3.0      adult

# %% [markdown]
# ## Analisis antiguedad por años

# %%
mean_yr = df2['clnt_tenure_yr'].mean().round(2)
min_yr = df2['clnt_tenure_yr'].min()
max_yr = df2['clnt_tenure_yr'].max()
range_yr = max_yr - min_yr

mean_yr, min_yr, max_yr, range_yr
# Out:
# (12.05, 2.0, 62.0, 60.0)

# %% [markdown]
# La media de antiguedad es 12 años
#
# el min es 2 años
#
# el max es 62 años
#
# Rango de antiguedad de 60 años

# %%
df2.clnt_tenure_yr.unique()
# Out:
# array([ 6.,  7.,  5., 16., 12., 30., 15.,  8.,  4.,  3., 10., 11., 13.,
#        14., 19., 18., 25., 23., 21., 17.,  9., 27., 24., 20., 28., 22.,
#        29., 46., 26., 32., 33., 35.,  2., 38., 31., 48., 34., 36., 51.,
#        47., 49., 37., 39., 40., 55., 42., 44., 43., 50., 54., 41., 45.,
#        52., 62.])

# %%
def categorize_age(tenure):
    if 0 <= tenure < 10:
        return 'nuevo'
    elif 10 <= tenure < 30:
        return 'regular'
    elif 30 <= tenure < 65:
        return 'fiel'
    else:
        return 'fuera de rango'

# Aplicar la función de mapeo a la columna 'edad' para crear la nueva columna 'rango de edad'
df2['grupo_antiguedad'] = df2['clnt_tenure_yr'].map(categorize_age)

# Mostrar el DataFrame resultante
df2.head(10)
# Out:
#    client_id  clnt_tenure_yr  clnt_age gender  num_accts        bal  \
# 0     836976             6.0      60.5      U        2.0   45105.30
# 1    2304905             7.0      58.0      U        2.0  110860.30
# 2    1439522             5.0      32.0      U        2.0   52467.79
# 3    1562045            16.0      49.0      M        2.0   67454.65
# 4    5126305            12.0      33.0      F        2.0  103671.75
# 5    3727881             5.0      30.5      U        2.0   23915.60
# 6     272934             5.0      58.5      U        2.0   27021.42
# 7     388801            30.0      57.5      M        5.0  522498.72
# 8     285619            30.0      67.5      M        2.0  299388.72
# 9    8198645            15.0      54.5      F        2.0  382303.83
#
#    calls_6_mnth  logons_6_mnth grupo_edad grupo_antiguedad
# 0           6.0            9.0     senior            nuevo
# 1           6.0            9.0      adult            nuevo
# ...

# %%
my_table = pd.crosstab(index = df2["grupo_antiguedad"],  
                              columns="count")      
my_table
# Out:
# col_0             count
# grupo_antiguedad
# fiel               1339
# nuevo             31620
# regular           37635

# %%
import seaborn as sns
sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_5088/2095407100.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");

# %% [markdown]
# Podemos ver que la mayoria de usuarios son regulares (de 10 a 30 años) sin embargo hay una gran cantidad de clientes nuevos (de 0 a 10 años)

# %%
my_table = pd.crosstab(index = df2["grupo_antiguedad"],  
                              columns="count")      
my_table
# Out:
# col_0             count
# grupo_antiguedad
# fiel               1339
# nuevo             31620
# regular           37635

# %%
df2.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_age gender  num_accts        bal  \
# 0     836976             6.0      60.5      U        2.0   45105.30
# 1    2304905             7.0      58.0      U        2.0  110860.30
# 2    1439522             5.0      32.0      U        2.0   52467.79
# 3    1562045            16.0      49.0      M        2.0   67454.65
# 4    5126305            12.0      33.0      F        2.0  103671.75
#
#    calls_6_mnth  logons_6_mnth grupo_edad grupo_antiguedad
# 0           6.0            9.0     senior            nuevo
# 1           6.0            9.0      adult            nuevo
# 2           6.0            9.0      adult            nuevo
# 3           3.0            6.0      adult          regular
# 4           0.0            3.0      adult          regular

# %% [markdown]
# ## Analisis de accounts

# %%
mean_accts = df2['num_accts'].mean().round(2)
min_accts = df2['num_accts'].min()
max_accts = df2['num_accts'].max()
range_accts = max_accts - min_accts

mean_accts, min_accts, max_accts, range_accts
# Out:
# (2.26, 1.0, 8.0, 7.0)

# %% [markdown]
# La media es de 2, 26 cuentas por usuario
#
# el minimo de cuentas es 1
# el maximo es de 8 cuentas
#
# lo que nos indica un rango de 7 cuentas

# %%
my_table = pd.crosstab(index = df2["num_accts"],  
                              columns="count")      
my_table
# Out:
# col_0      count
# num_accts
# 1.0            2
# 2.0        55496
# 3.0        12529
# 4.0         2241
# 5.0          284
# 6.0           33
# 7.0            8
# 8.0            1

# %%
sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");
# Out:
# /var/folders/cy/4jtvxlld09qd1srrzgj8fyy00000gp/T/ipykernel_5088/2993794703.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=my_table.index, y=my_table["count"], palette="Set3");

# %% [markdown]
# ## Analisis del balance

# %%
df2.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_age gender  num_accts        bal  \
# 0     836976             6.0      60.5      U        2.0   45105.30
# 1    2304905             7.0      58.0      U        2.0  110860.30
# 2    1439522             5.0      32.0      U        2.0   52467.79
# 3    1562045            16.0      49.0      M        2.0   67454.65
# 4    5126305            12.0      33.0      F        2.0  103671.75
#
#    calls_6_mnth  logons_6_mnth grupo_edad grupo_antiguedad
# 0           6.0            9.0     senior            nuevo
# 1           6.0            9.0      adult            nuevo
# 2           6.0            9.0      adult            nuevo
# 3           3.0            6.0      adult          regular
# 4           0.0            3.0      adult          regular

# %%
mean_bal = df2['bal'].mean().round(2)
min_bal = df2['bal'].min()
max_bal = df2['bal'].max()
range_bal = max_bal - min_bal

mean_bal, min_bal, max_bal, range_bal
# Out:
# (147446.73, 13789.419999999998, 16320040.15, 16306250.73)

# %%
df_bal = df2 [["client_id", "bal"]]
df_bal
# Out:
#        client_id         bal
# 0         836976    45105.30
# 1        2304905   110860.30
# 2        1439522    52467.79
# 3        1562045    67454.65
# 4        5126305   103671.75
# ...          ...         ...
# 70604    7993686  1411062.68
# 70605    8981690   101867.07
# 70606     333913    40745.00
# 70607    1573142   475114.69
# 70608    5602139   157498.73
#
# [70594 rows x 2 columns]

# %% [markdown]
# ## ¿Quiénes son los principales clientes que utilizan este proceso en línea?

# %%
df_bal = df_bal.sort_values(by = "bal", ascending=False)

# %%
df_bal.head()
# Out:
#        client_id          bal
# 39367    9286288  16320040.15
# 63746    8339240  12838418.01
# 23849    7070097   8986419.77
# 13318    9440656   8292996.21
# 2171     2291985   8247729.97

# %% [markdown]
# ## ¿Los clientes principales son más jóvenes o mayores, nuevos o antiguos?

# %%
df_bal_edad = df2 [["client_id", "bal", "grupo_edad"]]
df_bal_edad
# Out:
#        client_id         bal grupo_edad
# 0         836976    45105.30     senior
# 1        2304905   110860.30      adult
# 2        1439522    52467.79      adult
# 3        1562045    67454.65      adult
# 4        5126305   103671.75      adult
# ...          ...         ...        ...
# 70604    7993686  1411062.68      adult
# 70605    8981690   101867.07      adult
# 70606     333913    40745.00     senior
# 70607    1573142   475114.69     senior
# 70608    5602139   157498.73      adult
#
# [70594 rows x 3 columns]

# %%
df_bal_edad = df_bal_edad.sort_values(by = "bal", ascending=False)
df_bal_edad.head()
# Out:
#        client_id          bal grupo_edad
# 39367    9286288  16320040.15     senior
# 63746    8339240  12838418.01      young
# 23849    7070097   8986419.77      adult
# 13318    9440656   8292996.21     senior
# 2171     2291985   8247729.97      adult

# %%
df_bal_antiguedad = df2 [["client_id", "bal", "grupo_antiguedad"]]
df_bal_antiguedad
# Out:
#        client_id         bal grupo_antiguedad
# 0         836976    45105.30            nuevo
# 1        2304905   110860.30            nuevo
# 2        1439522    52467.79            nuevo
# 3        1562045    67454.65          regular
# 4        5126305   103671.75          regular
# ...          ...         ...              ...
# 70604    7993686  1411062.68            nuevo
# 70605    8981690   101867.07          regular
# 70606     333913    40745.00          regular
# 70607    1573142   475114.69          regular
# 70608    5602139   157498.73          regular
#
# [70594 rows x 3 columns]

# %%
df_bal_antiguedad = df_bal_antiguedad.sort_values(by = "bal", ascending=False)
df_bal_antiguedad.head()
# Out:
#        client_id          bal grupo_antiguedad
# 39367    9286288  16320040.15          regular
# 63746    8339240  12838418.01            nuevo
# 23849    7070097   8986419.77          regular
# 13318    9440656   8292996.21            nuevo
# 2171     2291985   8247729.97            nuevo

# %% [markdown]
# ## ¿Los clientes con mas antiguedad son los que mas cuentas tienen?

# %%
df_accts_antiguedad = df2 [["client_id", "num_accts", "grupo_antiguedad"]]
df_accts_antiguedad
# Out:
#        client_id  num_accts grupo_antiguedad
# 0         836976        2.0            nuevo
# 1        2304905        2.0            nuevo
# 2        1439522        2.0            nuevo
# 3        1562045        2.0          regular
# 4        5126305        2.0          regular
# ...          ...        ...              ...
# 70604    7993686        3.0            nuevo
# 70605    8981690        2.0          regular
# 70606     333913        2.0          regular
# 70607    1573142        3.0          regular
# 70608    5602139        3.0          regular
#
# [70594 rows x 3 columns]

# %%
df_accts_antiguedad = df_accts_antiguedad.sort_values(by = "num_accts", ascending=False)
df_accts_antiguedad.head()
# Out:
#        client_id  num_accts grupo_antiguedad
# 60093     281322        8.0          regular
# 5179     3549403        7.0          regular
# 60763    1991405        7.0          regular
# 23407    4106730        7.0            nuevo
# 1319     1068345        7.0            nuevo

# %%
df2.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_age gender  num_accts        bal  \
# 0     836976             6.0      60.5      U        2.0   45105.30
# 1    2304905             7.0      58.0      U        2.0  110860.30
# 2    1439522             5.0      32.0      U        2.0   52467.79
# 3    1562045            16.0      49.0      M        2.0   67454.65
# 4    5126305            12.0      33.0      F        2.0  103671.75
#
#    calls_6_mnth  logons_6_mnth grupo_edad grupo_antiguedad
# 0           6.0            9.0     senior            nuevo
# 1           6.0            9.0      adult            nuevo
# 2           6.0            9.0      adult            nuevo
# 3           3.0            6.0      adult          regular
# 4           0.0            3.0      adult          regular

# %%
df2.calls_6_mnth.unique()
# Out:
# array([6., 3., 0., 2., 1., 5., 4., 7.])

# %%
df2.calls_6_mnth.value_counts()
# Out:
# calls_6_mnth
# 6.0    14112
# 1.0    11016
# 2.0    10252
# 3.0     8752
# 0.0     7732
# 4.0     7174
# 5.0     6627
# 7.0     4929
# Name: count, dtype: int64

# %%
df2.logons_6_mnth.unique()
# Out:
# array([9., 6., 3., 5., 4., 8., 7., 1., 2.])

# %%
df2.logons_6_mnth.value_counts()
# Out:
# logons_6_mnth
# 9.0    12350
# 3.0    10243
# 4.0    10220
# 7.0     9892
# 5.0     9254
# 6.0     7878
# 8.0     4810
# 2.0     3009
# 1.0     2938
# Name: count, dtype: int64
